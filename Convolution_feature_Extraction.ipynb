# %%
import librosa
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import pathlib 
import IPython
import csv

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix



#Import Tensorflow
import tensorflow as tf
#Keras
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

import os
from PIL import Image

# %%
Main_prj_dir=os.chdir("/Users/shreevathsapk/Desktop/Miniprj");
Instrument_data=os.chdir("/Users/shreevathsapk/Desktop/Miniprj/instrumentdata")

# %%
cmap = plt.get_cmap('inferno')
plt.figure(figsize=(10,10))

#instruments = 'Bass_Acoustic Bass_electronic Bass_Synthetic Flute Guitar_Acoustic Guitar_electronic'.split()
instruments = 'Guitar_electronic'.split()

#retval = os.getcwd()
#print(retval)


for g in instruments:    #creates directory for each instrument features  
    
    pathlib.Path(f"/Users/shreevathsapk/Desktop/Miniprj/instrumentsamp/{g}").mkdir(parents=True, exist_ok=True)    
   
    print(g)
                 
    for filename in os.listdir(f'/Users/shreevathsapk/Desktop/Miniprj/instrumentdata/{g}'):
        if filename.endswith(('.mp3', '.wav', '.flac','.ogg')):
            print(filename)
        
            songname = f"/Users/shreevathsapk/Desktop/Miniprj/instrumentdata/{g}/{filename}"
            y, sr = librosa.load(songname, mono=True,duration=20)
        
            plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
            plt.axis('off');
            plt.savefig(f'/Users/shreevathsapk/Desktop/Miniprj/instrumentsamp/{g}/{filename[:-3].replace(".", "")}.png')
            print(y)
            #plt.clf() this was causing incomplete spectrums
# Out:
# Guitar_electronic
# guitar_electronic_028-091-127.wav
# [ 1.45122145e-08 -2.59080650e-08  1.44207730e-08 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00]
# guitar_electronic_022-054-100.wav
# [0.00269774 0.00986778 0.02118005 ... 0.         0.         0.        ]
# guitar_electronic_028-101-100.wav
# [ 1.31566713e-08 -6.07528294e-09 -1.13987495e-08 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00]
# guitar_electronic_022-067-127.wav
# [0.00116999 0.0050223  0.01574935 ... 0.         0.         0.        ]
# guitar_electronic_022-077-127.wav
# [-0.0025403  -0.0042941  -0.00458114 ...  0.          0.
#   0.        ]
# guitar_electronic_022-042-025.wav
# [0.00325837 0.00581769 0.00687479 ... 0.         0.         0.        ]
# guitar_electronic_022-026-100.wav
# [-0.0016775  -0.00130966  0.00151424 ...  0.          0.
#   0.        ]
# guitar_electronic_028-024-075.wav
# [-1.2955861e-07 -3.6397019e-08  2.0215747e-07 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00]
# ...
