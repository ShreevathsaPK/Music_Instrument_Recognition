# %%
# feature extractoring and preprocessing data
import librosa
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import pathlib 
import IPython
import csv

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix



#Import Tensorflow
import tensorflow as tf
#Keras
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

os.chdir("/Users/shreevathsapk/Desktop/Miniprj")

# %%
header = 'filename chroma_stft spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header = header.split()

# %%
file = open('execute.csv', 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
#instruments = 'piano strings'.split()
for filename in os.listdir(f'/Users/shreevathsapk/Desktop/Miniprj/executing_files'):
    if filename.endswith(('.mp3', '.wav', '.flac','.ogg')):
        print('/') #
        songname = f'/Users/shreevathsapk/Desktop/Miniprj/executing_files/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=30)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        #rmse=librosa.feature.rmse(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{filename} #{np.mean(chroma_stft)} #{np.mean(spec_cent)} #{np.mean(spec_bw)} #{np.mean(rolloff)} #{np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' #{np.mean(e)}'
        #to_append += f' #{g}'
        file = open('execute.csv', 'a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split("#"))
# Out:
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# /
# ...

# %%
exec_data = pd.read_csv('execute.csv')
exec_data
# Out:
#                                              filename  chroma_stft  \
# 0                                 flute new (43).wav      0.240382
# 1       flute_A5_phrase_mezzo-forte_tongued-slur.mp3      0.133086
# 2    flute_C5_phrase_mezzo-forte_triple-tonguing.mp3      0.167430
# 3                   flute_G4_1_pianissimo_normal.mp3      0.144603
# 4                      flute_F6_025_forte_normal.mp3      0.367517
# 5                flute_As5_05_mezzo-piano_normal.mp3      0.266543
# 6                                 flute new (14).wav      0.359651
# 7                flute_C4_025_mezzo-forte_normal.mp3      0.328473
# 8       flute_Fs5_very-long_cresc-decresc_normal.mp3      0.196419
# 9                      flute_A4_025_piano_normal.mp3      0.279417
# 10                flute_G4_15_mezzo-piano_normal.mp3      0.194129
# 11                               flute new (120).wav      0.278461
# 12                    flute_Cs4_025_forte_normal.mp3      0.396306
# ...
